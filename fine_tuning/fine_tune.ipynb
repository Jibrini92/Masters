# %%
import pandas as pd
from fine_tune_trainer_roberta import fine_tune_RoBERTa
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# ...

# %%
path = "path to the traning data"
df=pd.read_csv(path,index_col=0).reset_index(drop=True)

# %%
# keep text and label and change label to numerical format
df_data=df[["text","label"]]
df_data=df_data.replace({'label': {'E1': 0, "E2": 1,"E3": 2, "E4": 3, "E5": 4, "S1": 5, "S2": 6, "S3" : 7,"S4": 8, "G1": 9}})

# %%
# fine tune ( traning data, log directory, save directory)
fine_tune_RoBERTa(df_data,"roberta_final_top_no_zero_log","roberta_final_top_no_zero_save")
# Out:
# c:\Users\PCMC\anaconda3\lib\site-packages\transformers\optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#   0%|          | 0/5792 [00:00<?, ?it/s]
# {'loss': 2.2997, 'learning_rate': 1.0000000000000002e-06, 'epoch': 0.01}
# {'loss': 2.2939, 'learning_rate': 2.0000000000000003e-06, 'epoch': 0.01}
# {'loss': 2.2896, 'learning_rate': 3e-06, 'epoch': 0.02}
# {'loss': 2.2902, 'learning_rate': 4.000000000000001e-06, 'epoch': 0.03}
# {'loss': 2.257, 'learning_rate': 5e-06, 'epoch': 0.03}
# {'loss': 2.2329, 'learning_rate': 6e-06, 'epoch': 0.04}
# {'loss': 2.1845, 'learning_rate': 7.000000000000001e-06, 'epoch': 0.05}
# {'loss': 2.0995, 'learning_rate': 8.000000000000001e-06, 'epoch': 0.06}
# {'loss': 1.9521, 'learning_rate': 9e-06, 'epoch': 0.06}
# ...
