# %%
import pandas as pd
import os
import numpy as np
import openai
import matplotlib.pyplot as plt
openai.api_key = os.getenv('OPENAI_API_KEY')
from openai.embeddings_utils import cosine_similarity
# %matplotlib inline

# %%
#Read data with embeddings
mylist = []
for chunk in  pd.read_csv('E:\Masters backup\data_with_embeddings.csv', chunksize=20000, index_col=0):
    mylist.append(chunk)

big_data = pd.concat(mylist, axis= 0)
del mylist

# %%
big_data.head()
# Out:
#                                                 text   Company  year  \
# 0  Augmented reality makes the fascination of Por...   Porsche  2016
# 1  and encourage you, to confront, challenge and ...   Porsche  2016
# 2  For inspiration, consider the information re g...   Porsche  2016
# 3  The second volume is called Performance and co...   Porsche  2016
# 4  The two volumes may be different, but they hav...   Porsche  2016
#
#    n_tokens                                         embeddings
# 0        75  [-0.004225385375320911, 0.01583165116608143, 0...
# 1        89  [0.001987969968467951, -0.019381854683160782, ...
# 2        45  [-0.006319205742329359, 0.0064370157197117805,...
# 3        49  [-0.0010906282113865018, -0.025131287053227425...
# 4        54  [0.009442666545510292, 0.004147251136600971, 0...

# %%
df=pd.read_csv('..\Well_formed\\formness_data.csv', index_col=0)
df.head()
# Out:
#                                                 text   Company  year Label  \
# 0  Augmented reality makes the fascination of Por...   Porsche  2016    E1
# 1  and encourage you, to confront, challenge and ...   Porsche  2016    G1
# 2  For inspiration, consider the information re g...   Porsche  2016    G1
# 3  The second volume is called Performance and co...   Porsche  2016    E1
# 4  The two volumes may be different, but they hav...   Porsche  2016    E1
#
#    sim_score  Formness_score
# 0   0.721638        0.671054
# 1   0.802026        0.177600
# 2   0.779666        0.176960
# 3   0.797681        0.474855
# 4   0.750238        0.359458

# %%
df["embeddings"]=big_data["embeddings"]
df.head()
# Out:
#                                                 text   Company  year Label  \
# 0  Augmented reality makes the fascination of Por...   Porsche  2016    E1
# 1  and encourage you, to confront, challenge and ...   Porsche  2016    G1
# 2  For inspiration, consider the information re g...   Porsche  2016    G1
# 3  The second volume is called Performance and co...   Porsche  2016    E1
# 4  The two volumes may be different, but they hav...   Porsche  2016    E1
#
#    sim_score  Formness_score  \
# 0   0.721638        0.671054
# 1   0.802026        0.177600
# 2   0.779666        0.176960
# 3   0.797681        0.474855
# 4   0.750238        0.359458
#
#                                           embeddings
# 0  [-0.004225385375320911, 0.01583165116608143, 0...
# 1  [0.001987969968467951, -0.019381854683160782, ...
# 2  [-0.006319205742329359, 0.0064370157197117805,...
# 3  [-0.0010906282113865018, -0.025131287053227425...
# 4  [0.009442666545510292, 0.004147251136600971, 0...

# %%
del big_data

# %%
# Convert list of strings embeddings into list of floats
def list_to_float(embedding):
    return [float(x.strip(' []')) for x in embedding.split(',')]

# %%
df=df[df["Formness_score"]>=0.4].reset_index(drop=True)
df["embeddings"]=df["embeddings"].apply(list_to_float)

# %%
# For each label select 1000 entries with highest sim_score
df_E1=df[df["Label"]=="E1"].reset_index(drop=True)
df_E1=df_E1.nlargest(1000,"sim_score").reset_index(drop=True)
df_E2=df[df["Label"]=="E2"].reset_index(drop=True)
df_E2=df_E2.nlargest(1000,"sim_score").reset_index(drop=True)
df_E3=df[df["Label"]=="E3"].reset_index(drop=True)
df_E3=df_E3.nlargest(1000,"sim_score").reset_index(drop=True)
df_E4=df[df["Label"]=="E4"].reset_index(drop=True)
df_E4=df_E4.nlargest(1000,"sim_score").reset_index(drop=True)
df_E5=df[df["Label"]=="E5"].reset_index(drop=True)
df_E5=df_E5.nlargest(1000,"sim_score").reset_index(drop=True)
df_S1=df[df["Label"]=="S1"].reset_index(drop=True)
df_S1=df_S1.nlargest(1000,"sim_score").reset_index(drop=True)
df_S2=df[df["Label"]=="S2"].reset_index(drop=True)
df_S2=df_E1.nlargest(1000,"sim_score").reset_index(drop=True)
df_S3=df[df["Label"]=="S3"].reset_index(drop=True)
df_S3=df_S3.nlargest(1000,"sim_score").reset_index(drop=True)
df_S4=df[df["Label"]=="S4"].reset_index(drop=True)
df_S4=df_S4.nlargest(1000,"sim_score").reset_index(drop=True)
df_G1=df[df["Label"]=="G1"].reset_index(drop=True)
df_G1=df_G1.nlargest(1000,"sim_score").reset_index(drop=True)

# %%
# finds centroid of list of embeddings
def find_centroid(embeddings):
    centroid=[]
    coordinate=0
    for j in range(0,len(embeddings[0])):
        for i in range(0,len(embeddings)):
            coordinate+=embeddings[i][j]
        coordinate=coordinate/len(embeddings)
        centroid.append(coordinate)
    return centroid

# %%
# Find centroid for each label
E1_centroid=find_centroid(df_E1.embeddings)
E2_centroid=find_centroid(df_E2.embeddings)
E3_centroid=find_centroid(df_E3.embeddings)
E4_centroid=find_centroid(df_E4.embeddings)
E5_centroid=find_centroid(df_E5.embeddings)
S1_centroid=find_centroid(df_S1.embeddings)
S2_centroid=find_centroid(df_S2.embeddings)
S3_centroid=find_centroid(df_S3.embeddings)
S4_centroid=find_centroid(df_S4.embeddings)
G1_centroid=find_centroid(df_G1.embeddings)

# %%
centroid_list=[E1_centroid,E2_centroid,E3_centroid,E4_centroid,E5_centroid,S1_centroid,S2_centroid,S3_centroid,S4_centroid,G1_centroid]
labels_list=["E1","E2","E3","E4","E5","S1","S2","S3","S4","G1"]

# %%
# function takes similarity scores and returns sorted list of labels and coresponding scores
def sorted_embedings(sim):
    results_list=[]       
    for i in range(0,10):
        results_list.append([labels_list[i],sim[i]])
    results_list.sort(key = lambda i: i[1],reverse = True)
    return results_list

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
#find cosine similarity to each label centroid
centroid_labeling=[]
for i in range(0,len(df.embeddings)):
    sim = [cosine_similarity(df.embeddings.at[i], j) for j in centroid_list]
    centroid_labeling.append(sorted_embedings(sim))
    if i % 1000 == 0:
        logging.info("Rows done= {a} , {c} % done ".format(a=i,c=100*i/(len(df))))
# Out:
# INFO:root:Rows done= 0 , 0.0 % done
# INFO:root:Rows done= 1000 , 1.0578428468666694 % done
# INFO:root:Rows done= 2000 , 2.115685693733339 % done
# INFO:root:Rows done= 3000 , 3.1735285406000084 % done
# INFO:root:Rows done= 4000 , 4.231371387466678 % done
# INFO:root:Rows done= 5000 , 5.289214234333348 % done
# INFO:root:Rows done= 6000 , 6.347057081200017 % done
# INFO:root:Rows done= 7000 , 7.404899928066686 % done
# INFO:root:Rows done= 8000 , 8.462742774933355 % done
# INFO:root:Rows done= 9000 , 9.520585621800025 % done
# INFO:root:Rows done= 10000 , 10.578428468666695 % done
# INFO:root:Rows done= 11000 , 11.636271315533364 % done
# INFO:root:Rows done= 12000 , 12.694114162400034 % done
# INFO:root:Rows done= 13000 , 13.751957009266704 % done
# INFO:root:Rows done= 14000 , 14.809799856133372 % done
# INFO:root:Rows done= 15000 , 15.867642703000042 % done
# INFO:root:Rows done= 16000 , 16.92548554986671 % done
# INFO:root:Rows done= 17000 , 17.98332839673338 % done
# INFO:root:Rows done= 18000 , 19.04117124360005 % done
# INFO:root:Rows done= 19000 , 20.09901409046672 % done
# INFO:root:Rows done= 20000 , 21.15685693733339 % done
# INFO:root:Rows done= 21000 , 22.21469978420006 % done
# INFO:root:Rows done= 22000 , 23.272542631066727 % done
# INFO:root:Rows done= 23000 , 24.330385477933397 % done
# INFO:root:Rows done= 24000 , 25.388228324800068 % done
# INFO:root:Rows done= 25000 , 26.446071171666738 % done
# INFO:root:Rows done= 26000 , 27.503914018533408 % done
# INFO:root:Rows done= 27000 , 28.561756865400078 % done
# INFO:root:Rows done= 28000 , 29.619599712266744 % done
# INFO:root:Rows done= 29000 , 30.677442559133414 % done
# INFO:root:Rows done= 30000 , 31.735285406000084 % done
# INFO:root:Rows done= 31000 , 32.79312825286675 % done
# INFO:root:Rows done= 32000 , 33.85097109973342 % done
# INFO:root:Rows done= 33000 , 34.90881394660009 % done
# INFO:root:Rows done= 34000 , 35.96665679346676 % done
# INFO:root:Rows done= 35000 , 37.02449964033343 % done
# INFO:root:Rows done= 36000 , 38.0823424872001 % done
# INFO:root:Rows done= 37000 , 39.14018533406677 % done
# INFO:root:Rows done= 38000 , 40.19802818093344 % done
# INFO:root:Rows done= 39000 , 41.25587102780011 % done
# INFO:root:Rows done= 40000 , 42.31371387466678 % done
# INFO:root:Rows done= 41000 , 43.37155672153345 % done
# INFO:root:Rows done= 42000 , 44.42939956840012 % done
# INFO:root:Rows done= 43000 , 45.487242415266785 % done
# INFO:root:Rows done= 44000 , 46.545085262133455 % done
# INFO:root:Rows done= 45000 , 47.602928109000125 % done
# INFO:root:Rows done= 46000 , 48.660770955866795 % done
# INFO:root:Rows done= 47000 , 49.718613802733465 % done
# INFO:root:Rows done= 48000 , 50.776456649600135 % done
# INFO:root:Rows done= 49000 , 51.834299496466805 % done
# INFO:root:Rows done= 50000 , 52.892142343333475 % done
# INFO:root:Rows done= 51000 , 53.949985190200145 % done
# INFO:root:Rows done= 52000 , 55.007828037066815 % done
# INFO:root:Rows done= 53000 , 56.065670883933485 % done
# INFO:root:Rows done= 54000 , 57.123513730800155 % done
# INFO:root:Rows done= 55000 , 58.18135657766682 % done
# INFO:root:Rows done= 56000 , 59.23919942453349 % done
# INFO:root:Rows done= 57000 , 60.29704227140016 % done
# INFO:root:Rows done= 58000 , 61.35488511826683 % done
# INFO:root:Rows done= 59000 , 62.4127279651335 % done
# INFO:root:Rows done= 60000 , 63.47057081200017 % done
# INFO:root:Rows done= 61000 , 64.52841365886684 % done
# INFO:root:Rows done= 62000 , 65.5862565057335 % done
# INFO:root:Rows done= 63000 , 66.64409935260018 % done
# INFO:root:Rows done= 64000 , 67.70194219946684 % done
# INFO:root:Rows done= 65000 , 68.75978504633352 % done
# INFO:root:Rows done= 66000 , 69.81762789320018 % done
# INFO:root:Rows done= 67000 , 70.87547074006686 % done
# INFO:root:Rows done= 68000 , 71.93331358693352 % done
# INFO:root:Rows done= 69000 , 72.9911564338002 % done
# INFO:root:Rows done= 70000 , 74.04899928066686 % done
# INFO:root:Rows done= 71000 , 75.10684212753354 % done
# INFO:root:Rows done= 72000 , 76.1646849744002 % done
# INFO:root:Rows done= 73000 , 77.22252782126687 % done
# INFO:root:Rows done= 74000 , 78.28037066813354 % done
# INFO:root:Rows done= 75000 , 79.3382135150002 % done
# INFO:root:Rows done= 76000 , 80.39605636186688 % done
# INFO:root:Rows done= 77000 , 81.45389920873355 % done
# INFO:root:Rows done= 78000 , 82.51174205560022 % done
# INFO:root:Rows done= 79000 , 83.56958490246689 % done
# INFO:root:Rows done= 80000 , 84.62742774933356 % done
# INFO:root:Rows done= 81000 , 85.68527059620023 % done
# INFO:root:Rows done= 82000 , 86.7431134430669 % done
# INFO:root:Rows done= 83000 , 87.80095628993357 % done
# INFO:root:Rows done= 84000 , 88.85879913680024 % done
# INFO:root:Rows done= 85000 , 89.9166419836669 % done
# INFO:root:Rows done= 86000 , 90.97448483053357 % done
# INFO:root:Rows done= 87000 , 92.03232767740025 % done
# INFO:root:Rows done= 88000 , 93.09017052426691 % done
# INFO:root:Rows done= 89000 , 94.14801337113359 % done
# INFO:root:Rows done= 90000 , 95.20585621800025 % done
# INFO:root:Rows done= 91000 , 96.26369906486693 % done
# INFO:root:Rows done= 92000 , 97.32154191173359 % done
# INFO:root:Rows done= 93000 , 98.37938475860027 % done
# INFO:root:Rows done= 94000 , 99.43722760546693 % done

# %%
df["centroid_label"]=centroid_labeling

# %%
# extract top label and top score
centriod_labeling_top_label=[]
centriod_labeling_top_score=[]
for i in range(0,len(centroid_labeling)):
    centriod_labeling_top_label.append(centroid_labeling[i][0][0])
    centriod_labeling_top_score.append(centroid_labeling[i][0][1])

# %%
df["centriod_top_label"]=centriod_labeling_top_label
df["centriod_labeling_top_score"]=centriod_labeling_top_score

# %%
df.head()
# Out:
#                                                 text   Company  year Label  \
# 0  Augmented reality makes the fascination of Por...   Porsche  2016    E1
# 1  The second volume is called Performance and co...   Porsche  2016    E1
# 2  For the first time, Porsche has published a co...   Porsche  2016    E1
# 3  Over the course of the last financial year, Po...   Porsche  2016    G1
# 4  power of new technology. New variants of the 9...   Porsche  2016    E1
#
#    sim_score  Formness_score  \
# 0   0.721638        0.671054
# 1   0.797681        0.474855
# 2   0.781439        0.600305
# 3   0.746018        0.455402
# 4   0.752404        0.439552
#
#                                           embeddings  \
# 0  [-0.004225385375320911, 0.01583165116608143, 0...
# 1  [-0.0010906282113865018, -0.025131287053227425...
# 2  [-0.004911450203508139, -0.010176289826631546,...
# 3  [-0.006464285310357809, -0.004015290178358555,...
# 4  [-0.0030389458406716585, -0.02243526093661785,...
#
#                                       centroid_label centriod_top_label  \
# 0  [[S3, 0.8203358062811105], [S4, 0.817445893605...                 S3
# 1  [[S4, 0.8579721080134736], [S3, 0.854925281773...                 S4
# 2  [[S4, 0.863545253905563], [S3, 0.8587255541630...                 S4
# 3  [[S4, 0.8436447845652316], [S3, 0.839527532175...                 S4
# 4  [[E4, 0.8275159167501034], [S3, 0.823429067262...                 E4
#
#    centriod_labeling_top_score
# 0                     0.820336
# 1                     0.857972
# 2                     0.863545
# 3                     0.843645
# 4                     0.827516

# %%
df = df.rename(columns={'Label': 'adda_Label', 'centroid_label': 'cnetroid_label_list', 'centriod_top_label': 'centroid_label','centriod_labeling_top_score': 'centroid_score'})
df.head()
# Out:
#                                                 text   Company  year  \
# 0  Augmented reality makes the fascination of Por...   Porsche  2016
# 1  The second volume is called Performance and co...   Porsche  2016
# 2  For the first time, Porsche has published a co...   Porsche  2016
# 3  Over the course of the last financial year, Po...   Porsche  2016
# 4  power of new technology. New variants of the 9...   Porsche  2016
#
#   adda_Label  sim_score  Formness_score  \
# 0         E1   0.721638        0.671054
# 1         E1   0.797681        0.474855
# 2         E1   0.781439        0.600305
# 3         G1   0.746018        0.455402
# 4         E1   0.752404        0.439552
#
#                                           embeddings  \
# 0  [-0.004225385375320911, 0.01583165116608143, 0...
# 1  [-0.0010906282113865018, -0.025131287053227425...
# 2  [-0.004911450203508139, -0.010176289826631546,...
# 3  [-0.006464285310357809, -0.004015290178358555,...
# 4  [-0.0030389458406716585, -0.02243526093661785,...
#
#                                  cnetroid_label_list centroid_label  \
# 0  [[S3, 0.8203358062811105], [S4, 0.817445893605...             S3
# 1  [[S4, 0.8579721080134736], [S3, 0.854925281773...             S4
# 2  [[S4, 0.863545253905563], [S3, 0.8587255541630...             S4
# 3  [[S4, 0.8436447845652316], [S3, 0.839527532175...             S4
# 4  [[E4, 0.8275159167501034], [S3, 0.823429067262...             E4
#
#    centroid_score
# 0        0.820336
# 1        0.857972
# 2        0.863545
# 3        0.843645
# 4        0.827516

# %%
df.to_csv("centroid_data.csv",columns=["text","Company","year","adda_Label","sim_score","centroid_label","centroid_score","Formness_score"])
